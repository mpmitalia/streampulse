# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus
password = quote_plus('anagha@123')
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/streampulse')
connection = engine.connect()
print('Connected!')
# Out:
# Connected!
